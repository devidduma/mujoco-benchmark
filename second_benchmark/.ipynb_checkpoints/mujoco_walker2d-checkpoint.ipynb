# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
# !pip install -r ../requirements.txt --quiet
# Out:
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install envpool --quiet
# Out:
# ERROR: Could not find a version that satisfies the requirement envpool (from versions: none)
# ERROR: No matching distribution found for envpool
#
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !python ../mujoco_reinforce.py --task Walker2d-v4
# Out:
# Observations shape: (17,)
# Actions shape: (6,)
# Action range: -1.0 1.0
# Epoch #1: test_reward: 12.558736 ± 10.779807, best_reward: 12.558736 ± 10.779807 in #1
# Epoch #2: test_reward: 87.204935 ± 87.686377, best_reward: 87.204935 ± 87.686377 in #2
# Epoch #3: test_reward: 240.910639 ± 83.533575, best_reward: 240.910639 ± 83.533575 in #3
# Epoch #4: test_reward: 211.407090 ± 125.400553, best_reward: 240.910639 ± 83.533575 in #3
# Epoch #5: test_reward: 274.732125 ± 98.307420, best_reward: 274.732125 ± 98.307420 in #5
# Epoch #6: test_reward: 299.311038 ± 88.674737, best_reward: 299.311038 ± 88.674737 in #6
# Epoch #7: test_reward: 270.684067 ± 56.081829, best_reward: 299.311038 ± 88.674737 in #6
# Epoch #8: test_reward: 264.113333 ± 72.739035, best_reward: 299.311038 ± 88.674737 in #6
# Epoch #9: test_reward: 290.493579 ± 103.014343, best_reward: 299.311038 ± 88.674737 in #6
# Epoch #10: test_reward: 255.873828 ± 116.712453, best_reward: 299.311038 ± 88.674737 in #6
# ...

# %%
# !python ../mujoco_a2c.py --task Walker2d-v4
# Out:
# Observations shape: (17,)
# Actions shape: (6,)
# Action range: -1.0 1.0
# Epoch #1: test_reward: 252.011754 ± 107.582629, best_reward: 252.011754 ± 107.582629 in #1
# Epoch #2: test_reward: 169.304651 ± 194.318919, best_reward: 252.011754 ± 107.582629 in #1
# Epoch #3: test_reward: 61.853563 ± 51.281146, best_reward: 252.011754 ± 107.582629 in #1
# Epoch #4: test_reward: 105.370732 ± 89.104619, best_reward: 252.011754 ± 107.582629 in #1
# Epoch #5: test_reward: 334.676681 ± 181.865758, best_reward: 334.676681 ± 181.865758 in #5
# Epoch #6: test_reward: 1298.971285 ± 295.882166, best_reward: 1298.971285 ± 295.882166 in #6
# Epoch #7: test_reward: 514.894453 ± 220.719200, best_reward: 1298.971285 ± 295.882166 in #6
# Epoch #8: test_reward: 720.811479 ± 161.742437, best_reward: 1298.971285 ± 295.882166 in #6
# Epoch #9: test_reward: 894.845778 ± 183.866716, best_reward: 1298.971285 ± 295.882166 in #6
# ...

# %%
# !python ../mujoco_npg.py --task Walker2d-v4
# Out:
# Observations shape: (17,)
# Actions shape: (6,)
# Action range: -1.0 1.0
# Epoch #1: test_reward: 122.733919 ± 96.454442, best_reward: 122.733919 ± 96.454442 in #1
# Epoch #2: test_reward: 269.856123 ± 163.309245, best_reward: 269.856123 ± 163.309245 in #2
# Epoch #3: test_reward: 287.066490 ± 50.903332, best_reward: 287.066490 ± 50.903332 in #3
# Epoch #4: test_reward: 304.163342 ± 33.574117, best_reward: 304.163342 ± 33.574117 in #4
# Epoch #5: test_reward: 312.908072 ± 46.451472, best_reward: 312.908072 ± 46.451472 in #5
# Epoch #6: test_reward: 350.348520 ± 42.774441, best_reward: 350.348520 ± 42.774441 in #6
# Epoch #7: test_reward: 405.206447 ± 86.871471, best_reward: 405.206447 ± 86.871471 in #7
# Epoch #8: test_reward: 450.972894 ± 61.059239, best_reward: 450.972894 ± 61.059239 in #8
# Epoch #9: test_reward: 520.027501 ± 79.191554, best_reward: 520.027501 ± 79.191554 in #9
# Epoch #10: test_reward: 550.340769 ± 150.086884, best_reward: 550.340769 ± 150.086884 in #10
# ...

# %%
# !python ../mujoco_trpo.py --task Walker2d-v4
# Out:
# Observations shape: (17,)
# Actions shape: (6,)
# Action range: -1.0 1.0
# Epoch #1: test_reward: 229.399983 ± 65.254520, best_reward: 229.399983 ± 65.254520 in #1
# Epoch #2: test_reward: 270.433979 ± 56.540970, best_reward: 270.433979 ± 56.540970 in #2
# Epoch #3: test_reward: 351.450157 ± 31.742884, best_reward: 351.450157 ± 31.742884 in #3
# Epoch #4: test_reward: 395.628083 ± 37.901007, best_reward: 395.628083 ± 37.901007 in #4
# Epoch #5: test_reward: 419.384620 ± 67.638131, best_reward: 419.384620 ± 67.638131 in #5
# Epoch #6: test_reward: 420.163065 ± 53.489928, best_reward: 420.163065 ± 53.489928 in #6
# Epoch #7: test_reward: 459.415063 ± 64.138496, best_reward: 459.415063 ± 64.138496 in #7
# Epoch #8: test_reward: 501.225733 ± 70.232319, best_reward: 501.225733 ± 70.232319 in #8
# Epoch #9: test_reward: 520.259513 ± 81.658775, best_reward: 520.259513 ± 81.658775 in #9
# Epoch #10: test_reward: 683.745672 ± 91.489702, best_reward: 683.745672 ± 91.489702 in #10
# ...

# %%
# !python ../mujoco_ppo.py --task Walker2d-v4
# Out:
# Observations shape: (17,)
# G:\DD\mujoco-benchmark\mujoco_env.py:26: UserWarning: Recommend using envpool (pip install envpool) to run Mujoco environments more efficiently.
#   warnings.warn(
#
# ...
# Epoch #1:  96%|#########5| 28672/30000 [00:33<00:01, 861.21it/s, env_step=28672, len=219, loss=-0.453, loss/clip=-0.462, loss/ent=4.955, loss/vf=0.035, n/ep=12, n/st=2048, rew=274.98]
# Epoch #1: 30720it [00:33, 858.60it/s, env_step=28672, len=219, loss=-0.453, loss/clip=-0.462, loss/ent=4.955, loss/vf=0.035, n/ep=12, n/st=2048, rew=274.98]
# Epoch #1: 30720it [00:35, 858.60it/s, env_step=30720, len=191, loss=-0.572, loss/clip=-0.581, loss/ent=4.922, loss/vf=0.037, n/ep=5, n/st=2048, rew=286.05]
# Epoch #1: 30720it [00:35, 858.27it/s, env_step=30720, len=191, loss=-0.572, loss/clip=-0.581, loss/ent=4.922, loss/vf=0.037, n/ep=5, n/st=2048, rew=286.05]
#
# ...

# %%
# !python ../mujoco_ddpg.py --task Walker2d-v4
# Out:
# Observations shape: (17,)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Actions shape: (6,)
# Action range: -1.0 1.0
# Epoch #1: test_reward: 31.710990 ± 17.988621, best_reward: 31.710990 ± 17.988621 in #1
# Epoch #2: test_reward: -7.889411 ± 43.374841, best_reward: 31.710990 ± 17.988621 in #1
# Epoch #3: test_reward: 192.422601 ± 209.479751, best_reward: 192.422601 ± 209.479751 in #3
# Epoch #4: test_reward: 145.556858 ± 73.940195, best_reward: 192.422601 ± 209.479751 in #3
# Epoch #5: test_reward: 3.761647 ± 9.571432, best_reward: 192.422601 ± 209.479751 in #3
# Epoch #6: test_reward: 1.119376 ± 8.744532, best_reward: 192.422601 ± 209.479751 in #3
# ...

# %%
# !python ../mujoco_td3.py --task Walker2d-v4
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
# !python ../mujoco_sac.py --task Walker2d-v4

# %%
# !python ../mujoco_redq.py --task Walker2d-v4
